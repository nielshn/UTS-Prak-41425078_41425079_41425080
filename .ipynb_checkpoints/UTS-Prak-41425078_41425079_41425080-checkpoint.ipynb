# %%
# Import library dan konfigurasi
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from scipy import stats
from sklearn.utils import resample
from scipy.stats.mstats import winsorize
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 1️⃣ Data Collection

# %%
# ## 1. Data Collection

# Load data
path = 'data.csv'
try:
    df = pd.read_csv(path, sep=';')
except Exception as e:
    # fallback: coba deteksi separator
    df = pd.read_csv(path)

print('Shape:', df.shape)
df.head()
# Out:
# Shape: (4424, 37)
#    Marital status  Application mode  Application order  Course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime/evening attendance\t  Previous qualification  \
# 0                             1                       1
# 1                             1                       1
# 2                             1                       1
# 3                             1                       1
# 4                             0                       1
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           122.0            1                      19
# 1                           160.0            1                       1
# ...

# %% [markdown]
# **Insight:**
# Data berhasil dimuat ke dalam DataFrame. Jumlah baris dan kolom sesuai kebutuhan analisis, serta terdapat fitur numerik dan kategorikal yang siap dieksplorasi.
#
# **Interpretasi:**
# Langkah ini memastikan data sudah tersedia dan siap untuk proses analisis lebih lanjut.

# %% [markdown]
# ### 2️⃣ Data Visualization

# %% [markdown]
# #### a. Histogram

# %%
# asumsi: kolom 'math_score', 'reading_score', 'writing_score', 'gender', 'parental_level_of_education'
numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()
cat_cols = df.select_dtypes(include=['object', 'category']).columns.tolist()
print('Numeric cols sample:', numeric_cols[:8])
print('Categorical cols sample:', cat_cols[:8])

# 2.1 Histogram (distribusi nilai salah satu numeric feature)
col = numeric_cols[0] if numeric_cols else None
if col:
    plt.figure(figsize=(8,4))
    plt.hist(df[col].dropna(), bins=30)
    plt.title(f'Histogram of {col} — memilih histogram untuk melihat distribusi dan skewness')
    plt.xlabel(col)
    plt.ylabel('count')
    plt.show()
# Out:
# Numeric cols sample: ['Marital status', 'Application mode', 'Application order', 'Course', 'Daytime/evening attendance\t', 'Previous qualification', 'Previous qualification (grade)', 'Nacionality']
# Categorical cols sample: ['Target']

# %% [markdown]
# **Insight:**
# Histogram memperlihatkan distribusi nilai pada fitur numerik utama. Misal: Jika distribusi miring ke kanan (right-skewed), berarti lebih banyak siswa dengan nilai rendah.
#
# **Interpretasi:**
# Distribusi data dapat membantu memahami pola umum, mendeteksi outlier, dan menentukan apakah data perlu transformasi sebelum analisis lebih lanjut.

# %% [markdown]
# #### b. Boxplot

# %%
# 2.2 Boxplot (detect outliers & compare groups)
if col and cat_cols:
    group = cat_cols[0]
    plt.figure(figsize=(10,5))
    sns.boxplot(x=df[group], y=df[col])
    plt.title(f'Boxplot of {col} by {group} — alasan: deteksi outlier dan perbandingan antar-group')
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# **Insight:**
# Boxplot menunjukkan perbandingan nilai antar kelompok (misal: gender) dan mendeteksi outlier.
#
# **Interpretasi:**
# Jika median salah satu kelompok lebih tinggi, berarti kelompok tersebut cenderung memiliki nilai lebih baik. Outlier yang muncul dapat mempengaruhi hasil analisis statistik.

# %% [markdown]
# #### c. Scatter Plot

# %%
# 2.3 Scatter plot (hubungan antar dua numeric features)
if len(numeric_cols) >= 2:
    xcol, ycol = numeric_cols[:2]
    plt.figure(figsize=(7,5))
    plt.scatter(df[xcol], df[ycol], alpha=0.5)
    plt.title(f'Scatter {xcol} vs {ycol} — alasan: melihat korelasi/linearitas')
    plt.xlabel(xcol)
    plt.ylabel(ycol)
    plt.show()

# %% [markdown]
# **Insight:**
# Scatter plot memperlihatkan hubungan antara dua fitur numerik, misal korelasi antara skor matematika dan membaca.
#
# **Interpretasi:**
# Jika titik-titik membentuk pola linear, berarti ada korelasi antara kedua fitur. Korelasi positif berarti kenaikan satu fitur diikuti kenaikan fitur lain.

# %% [markdown]
# #### d. Heatmap Korelasi

# %%
# 2.4 Heatmap korelasi (overview hubungan antar fitur numeric)
if numeric_cols:
    plt.figure(figsize=(12,8))
    corr = df[numeric_cols].corr()
    sns.heatmap(corr, annot=True, fmt='.2f', cmap='coolwarm')
    plt.title('Heatmap korelasi antar numeric features — alasan: identifikasi fitur berkorelasi tinggi')
    plt.show()

# %% [markdown]
# **Insight:**
# Heatmap menampilkan kekuatan korelasi antar fitur numerik.
#
# **Interpretasi:**
# Fitur dengan korelasi tinggi dapat dipertimbangkan untuk reduksi dimensi atau feature selection. Korelasi negatif/positif yang kuat bisa menjadi dasar analisis lebih lanjut.

# %% [markdown]
# ### 3️⃣ Data Processing and Techniques (Advance Preprocessing)
#
# - Handling missing values (KNN imputation)
# - Handling outliers (IQR trimming & Winsorization)
# - Feature scaling (Standardization)
# - Encoding categorical variables (One-Hot)
# - Feature reduction (PCA)
#
# #### a. Handling Missing Values

# %%
# 3. Data Processing and Techniques (Advance Preprocessing)

# 3.1 Cek missing values
missing = df.isnull().sum().sort_values(ascending=False)
missing[missing>0].head(20)

# 3.2 Imputation: KNNImputer untuk numeric
num_imputer = KNNImputer(n_neighbors=5)
if numeric_cols:
    df_num = df[numeric_cols]
    df_num_imputed = pd.DataFrame(num_imputer.fit_transform(df_num), columns=numeric_cols)
else:
    df_num_imputed = pd.DataFrame()

# Untuk kategori: fillna dengan mode per kolom
df_cat = df[cat_cols].fillna(df[cat_cols].mode().iloc[0]) if cat_cols else pd.DataFrame()

# gabungkan kembali
df_imputed = pd.concat([df_num_imputed, df_cat.reset_index(drop=True)], axis=1)
print('After imputation shape:', df_imputed.shape)
# Out:
# After imputation shape: (4424, 37)

# %% [markdown]
# **Insight:**
# Missing values pada fitur numerik diimputasi dengan KNNImputer, sedangkan fitur kategorikal diisi dengan modus.
#
# **Interpretasi:**
# Mengurangi missing value meningkatkan kualitas data dan mencegah bias pada analisis/modeling.

# %% [markdown]
# #### b. Handling Outliers

# %%
# 3.3 Handling outliers: IQR trimming (example) + Winsorization
# Pilih satu numeric kolom contoh untuk demonstrasi
if numeric_cols:
    target_col = numeric_cols[0]
    q1 = df_imputed[target_col].quantile(0.25)
    q3 = df_imputed[target_col].quantile(0.75)
    iqr = q3 - q1
    lower = q1 - 1.5 * iqr
    upper = q3 + 1.5 * iqr
    print(f'IQR bounds for {target_col}:', lower, upper)
    # trimming example
    df_trimmed = df_imputed[(df_imputed[target_col] >= lower) & (df_imputed[target_col] <= upper)]
    print('Trimmed shape:', df_trimmed.shape)
    # Winsorize example (limit the extremes to 5th and 95th percentiles)
    df_wins = df_imputed.copy()
    pct_low = df_wins[target_col].quantile(0.05)
    pct_high = df_wins[target_col].quantile(0.95)
    df_wins[target_col] = np.where(df_wins[target_col] < pct_low, pct_low, df_wins[target_col])
    df_wins[target_col] = np.where(df_wins[target_col] > pct_high, pct_high, df_wins[target_col])
# Out:
# IQR bounds for Marital status: 1.0 1.0
# Trimmed shape: (3919, 37)

# %% [markdown]
# **Insight:**
# Outlier ditangani dengan trimming (menghapus data ekstrem) dan winsorization (mengganti nilai ekstrem dengan batas tertentu).
#
# **Interpretasi:**
# Menangani outlier penting agar hasil analisis statistik dan model tidak bias akibat data ekstrem.

# %% [markdown]
# #### c. Feature Scaling

# %%
# 3.4 Feature scaling
scaler = StandardScaler()
if numeric_cols:
    df_scaled_num = pd.DataFrame(scaler.fit_transform(df_imputed[numeric_cols]), columns=numeric_cols)
else:
    df_scaled_num = pd.DataFrame()

# %% [markdown]
# **Insight:**
# Fitur numerik dinormalisasi agar memiliki skala yang sama.
#
# **Interpretasi:**
# Scaling penting untuk algoritma machine learning yang sensitif terhadap skala data, seperti KNN dan PCA.

# %% [markdown]
# #### d. Encoding Categorical Variables

# %%
# 3.5 Encoding categorical variables (One-Hot)
if cat_cols:
    ohe = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
    cat_transformed = pd.DataFrame(ohe.fit_transform(df_imputed[cat_cols]))
    cat_transformed.columns = ohe.get_feature_names_out(cat_cols)
else:
    cat_transformed = pd.DataFrame()

# gabungkan scaled numeric + encoded cat
df_preprocessed = pd.concat([df_scaled_num.reset_index(drop=True), cat_transformed.reset_index(drop=True)], axis=1)
print('Preprocessed shape:', df_preprocessed.shape)
# Out:
# Preprocessed shape: (4424, 39)

# %% [markdown]
# **Insight:**
# Fitur kategorikal diubah menjadi bentuk numerik dengan One-Hot Encoding.
#
# **Interpretasi:**
# Encoding memungkinkan fitur kategorikal digunakan dalam analisis statistik dan machine learning.

# %% [markdown]
# #### e. Feature Reduction (PCA).

# %%
# 3.6 Feature Reduction: PCA (mengurangi dimensi untuk visualisasi / modeling)
n_components = min(10, df_preprocessed.shape[1])
pca = PCA(n_components=n_components)
if df_preprocessed.shape[0] > 0 and df_preprocessed.shape[1] > 0:
    pca_result = pca.fit_transform(df_preprocessed.fillna(0))
    explained = pca.explained_variance_ratio_.cumsum()
    print('Explained variance by components:', explained)
# Out:
# Explained variance by components: [0.17512078 0.27491447 0.33280355 0.3878463  0.44019523 0.48616691
#  0.52977705 0.57192828 0.60720988 0.64126762]

# %% [markdown]
# **Insight:**
# PCA mengurangi dimensi data dan mempercepat proses modeling.
#
# **Interpretasi:**
# PCA membantu visualisasi dan mengurangi risiko overfitting dengan mengurangi jumlah fitur tanpa kehilangan banyak informasi.

# %% [markdown]
# ### 4️⃣ Statistical Analysis
#
# #### a. Uji Parametrik (T-Test)

# %%
# 4. Statistical Analysis
# - Minimal 1 uji parametrik (contoh: independent t-test atau ANOVA)
# - Minimal 1 uji non-parametrik (contoh: Spearman correlation atau Mann-Whitney U)
# - Sertakan interpretasi p-value, effect size (misal Cohen's d), dan confidence interval jika relevan.

# bandingkan mean `target_col` antara 2 group
if target_col and cat_cols:
    group_col = cat_cols[0]
    groups = df_imputed[group_col].dropna().unique()
    if len(groups) >= 2:
        g1, g2 = groups[:2]
        data1 = df_imputed[df_imputed[group_col] == g1][target_col]
        data2 = df_imputed[df_imputed[group_col] == g2][target_col]
        # Parametric test: independent t-test
        tstat, pval = stats.ttest_ind(data1, data2, equal_var=False, nan_policy='omit')
        # effect size: Cohen's d
        def cohens_d(x, y):
            nx = len(x); ny = len(y)
            dof = nx + ny - 2
            pooled_std = np.sqrt(((nx - 1) * x.std(ddof=1) ** 2 + (ny - 1) * y.std(ddof=1) ** 2) / dof)
            return (x.mean() - y.mean()) / pooled_std
        d = cohens_d(data1.dropna(), data2.dropna())
        print(f'T-test between {g1} and {g2} on {target_col}: t={tstat:.3f}, p={pval:.4f}, Cohen\'s d={d:.3f}')
        # Confidence interval for difference in means via bootstrap
        diffs = []
        for i in range(1000):
            s1 = resample(data1.dropna(), replace=True)
            s2 = resample(data2.dropna(), replace=True)
            diffs.append(s1.mean() - s2.mean())
        ci_low, ci_high = np.percentile(diffs, [2.5, 97.5])
        print(f'95% CI for mean difference: ({ci_low:.3f}, {ci_high:.3f})')
# Out:
# T-test between Dropout and Graduate on Marital status: t=5.690, p=0.0000, Cohen's d=0.207
# 95% CI for mean difference: (0.084, 0.171)

# %% [markdown]
# **Insight:**
# T-test membandingkan rata-rata fitur target antara dua kelompok. Nilai p-value menunjukkan signifikansi perbedaan, Cohen's d menunjukkan besar efek, dan confidence interval menunjukkan rentang perbedaan rata-rata.
#
# **Interpretasi:**
# Jika p-value < 0.05, perbedaan rata-rata signifikan secara statistik. Effect size besar menunjukkan perbedaan yang bermakna secara praktis.
#
# #### b. Uji Non-Parametrik (Spearman/Mann-Whitney)

# %%
# Non-parametric test: Spearman correlation between two numeric variables
if len(numeric_cols) >= 2:
    xcol, ycol = numeric_cols[:2]
    rho, p_spearman = stats.spearmanr(df[xcol].dropna(), df[ycol].dropna())
    print(f"Spearman correlation {xcol} vs {ycol}: rho={rho:.3f}, p={p_spearman:.4f}")

# Another non-parametric: Mann-Whitney U (if two groups)
if target_col and cat_cols and len(groups) >= 2:
    u_stat, p_mw = stats.mannwhitneyu(data1, data2, alternative='two-sided')
    print(f"Mann-Whitney U between {g1} and {g2} on {target_col}: U={u_stat}, p={p_mw:.4f}")
# Out:
# Spearman correlation Marital status vs Application mode: rho=0.270, p=0.0000
# Mann-Whitney U between Dropout and Graduate on Marital status: U=1693617.0, p=0.0000

# %% [markdown]
# **Insight:**
# Spearman correlation mengukur hubungan monotonic antar dua fitur numerik. Mann-Whitney U test membandingkan distribusi dua kelompok tanpa asumsi normalitas.
#
# **Interpretasi:**
# Jika p-value < 0.05, terdapat hubungan atau perbedaan signifikan antar kelompok/fitur. Cocok digunakan jika data tidak normal.

# %%
# 5. Reporting & Saving

# Save preprocessed data
out_path = 'preprocessed_student_performance.csv'
df_preprocessed.to_csv(out_path, index=False)
print('Saved preprocessed data to', out_path)
# Out:
# Saved preprocessed data to preprocessed_student_performance.csv
